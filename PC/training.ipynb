# %%
from ultralytics import YOLO
import torch

# is cuda available?
print("CUDA available: ", torch.cuda.is_available())
# Out:
# CUDA available:  True

# %%
# Load a model
model = YOLO('yolov8n.pt')  # load a custom trained model

# Train the model
results = model.train(data='data_custom2.yaml', epochs=200, imgsz=640, batch=-1, device=0, workers=3)
# Out:
# New https://pypi.org/project/ultralytics/8.0.212 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200  Python-3.11.5 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %%
model=YOLO('runs/detect/train2/weights/best.pt')
result = model.predict('tough-crowd.png', save=True)
# Out:
# image 1/1 d:\!Programy\Inzynierka\trzeci_trening\tough-crowd.png: 448x640 14 faces, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict
